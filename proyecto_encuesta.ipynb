# %%
path_to_file_1 = '2021.2 - sysarmy - Encuesta de remuneración salarial Argentina - Argentina.csv'

path_to_file_2 = '2021.2 - sysarmy - Encuesta de remuneración salarial Latam - Latam.csv'

with open(f"{path_to_file_1}", "r") as f:
    for linea in iter(f.readline, ''):
        print(linea)
        

        
with open(f"{path_to_file_2}", "r") as f:
    for linea in iter(f.readline, ''):
        print(linea)
# Out:
# Para analizar los resultados podÃ©s bajar el .csv (Archivo > Descargar como),,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# RecordÃ¡ calificar a la empresa donde estÃ¡s trabajando en www.openqube.io,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# UsÃ¡ el cÃ³digo ENCUESTA en la tienda de sysarmy y llevate un 10% de descuento!,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,Esta obra estÃ¡ bajo una Licencia Creative Commons AtribuciÃ³n-NoComercial-CompartirIgual 4.0 Internacional.,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,
#
# DÃ³nde estÃ¡s trabajando,Tipo de contrato,Salario mensual o retiro BRUTO (en tu moneda local),Salario mensual o retiro NETO (en tu moneda local),Pagos en dÃ³lares,Â¿CuÃ¡l fue el Ãºltimo valor de dÃ³lar que tomaron?,Â¿QuÃ© tan conforme estÃ¡s con tu sueldo?,CÃ³mo creÃ©s que estÃ¡ tu sueldo con respecto al Ãºltimo semestre,RecibÃ­s algÃºn tipo de bono,A quÃ© estÃ¡ atado el bono,Â¿Tuviste ajustes por inflaciÃ³n durante 2021?,Â¿De quÃ© % fue el ajuste total?,Â¿En quÃ© mes fue el Ãºltimo ajuste?,Trabajo de,AÃ±os de experiencia,AÃ±os en la empresa actual,AÃ±os en el puesto actual,Â¿Gente a cargo?,Plataformas,Lenguajes de programaciÃ³n o tecnologÃ­as.,"Frameworks, herramientas y librerÃ­as",Bases de datos,QA / Testing,IDEs,Cantidad de personas en tu organizaciÃ³n,Trabajo para una empresa que no tiene oficina en mi ciudad,Actividad principal,Â¿La recomendÃ¡s como un buen lugar para trabajar?,Â¿CÃ³mo calificÃ¡s las polÃ­ticas de diversidad e inclusiÃ³n?,Beneficios extra,Â¿Salir o seguir contestando?,Nivel de estudios alcanzado,Estado,Carrera,Universidad,Realizaste cursos de especializaciÃ³n,Â¿ContribuÃ­s a proyectos open source?,Â¿ProgramÃ¡s como hobbie?,Â¿Salir o seguir contestando?,Â¿TenÃ©s guardias?,CuÃ¡nto cobrÃ¡s por guardia,"Â¿Porcentaje, bruto o neto?",Â¿Salir o seguir contestando?,Â¿Sufriste o presenciaste situaciones de violencia laboral?,Â¿TenÃ©s algÃºn tipo de discapacidad?,Â¿SentÃ­s que esto te dificultÃ³ el conseguir trabajo?,Â¿Salir o seguir contestando?,Â¿CÃ³mo venÃ­s llevando la pandemia?,Â¿TenÃ©s hijos/as menores de edad?,Â¿Con cuÃ¡ntas personas estÃ¡s conviviendo?,Â¿Con quiÃ©nes convivÃ­s?,Â¿TenÃ©s un espacio dedicado para el trabajo?,Â¿TenÃ©s que compartir tu equipo de trabajo con alguien?,Â¿QuÃ© tipo de cuarentena hiciste / estÃ¡s haciendo?,Â¿CambiÃ³ tu situaciÃ³n laboral a raÃ­z de la pandemia?,Â¿QuÃ© tanto sentÃ­s que te estÃ¡ apoyando tu empresa/organizaciÃ³n en esta situaciÃ³n?,Â¿CÃ³mo se vio afectada tu empresa/organizaciÃ³n?,Â¿Instauraron algÃºn beneficio nuevo?,Tengo,Me identifico
#
# Catamarca,Full-Time,245000,169000,,,2,3,De uno a tres sueldos,Mix de las anteriores,Uno,40,4,Developer,3,0,3,0,Firebase,"CSS, HTML, Javascript, TypeScript","React.js, react native",Ninguna de las anteriores,Jest,"Android Studio, Visual Studio Code, Xcode",51-100,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,6,4,"Capacitaciones y/o cursos, Comidas pagas / subvencionadas, Horarios flexibles, Licencia de paternidad / maternidad extendida, Vacaciones flexibles (adicionales a las reglamentarias)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,28,VarÃ³n Cis
#
# Catamarca,Tercerizado (trabajo a travÃ©s de consultora o agencia),180000,126000,,,3,2,No,No recibo bono,Uno,33,3,Technical Leader,9,0,0,0,"Amazon Web Services, Linux, Windows Server",Python,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Notepad++,10001+,Trabajo para una empresa que no tiene oficina en mi ciudad,Otras industrias,9,10,Horarios flexibles,Quiero responder mÃ¡s preguntas,Universitario,Completado,Lic. En redes y comunicaciÃ³n de datos ,UP - Universidad de Palermo,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",SÃ­,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,34,VarÃ³n Cis
#
# Catamarca,Full-Time,71202,61753,,nose ,1,1,No,No recibo bono,Dos,12,7,Networking,16,12,12,1,"Azure, Google Cloud Platform/App Engine, Linux, VMWare, Windows Server","C++, COBOL, Matlab, Python",Ninguno de los anteriores,SQLite,Ninguna de las anteriores,Ninguno de los anteriores,51-100,,Otras industrias,8,9,"Abono de celular, Capacitaciones y/o cursos",Quiero responder mÃ¡s preguntas,Universitario,Incompleto,IngenierÃ­a ElectrÃ³nica,Universidad nacional de catamarca,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,"SÃ­, pasiva",0,Neto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,No,Ya colaborÃ© lo suficiente,,,,,,,,,,,,45,VarÃ³n Cis
#
# Chaco,Part-Time,96000,96000,,,2,2,No,No recibo bono,No,0,0,Developer,4,0,0,0,Azure,"CSS, HTML, Javascript, PHP","Bootstrap, Yii",MySQL,Ninguna de las anteriores,PHPStorm,51-100,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,7,8,"Abono de Internet, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas",Quiero responder mÃ¡s preguntas,Universitario,Completado,Licenciatura en Sistemas de InformaciÃ³n,Unne,"SÃ­, de forma particular",No,No,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,4,0,1,Pareja,SÃ­,No,2,"CambiÃ© de trabajo, pero no por la pandemia",9,No la afectÃ³,Ninguna de las anteriores,31,Mujer Cis
#
# Chaco,Full-Time,42000,32000,,,1,2,No,Performance individual,Uno,1,3,Developer,7,5,5,0,"Amazon Web Services, Docker, Microcontroladores","Bash/Shell, CSS, HTML, Java, Javascript, PHP, Python, SQL","Bootstrap, Drupal, Flask, jQuery, Laravel, Node.js, Vue.js","MySQL, PostgreSQL, Redis","Cypress, Jest, PHPUnit, Postman, Selenium","IPython / Jupyter, PHPStorm, Vim, Visual Studio Code",11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,5,3,Horarios flexibles,Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En mi trabajo actual,,,Ya colaborÃ© lo suficiente,,,,,,,,,,,,30,VarÃ³n Cis
#
# Chaco,Freelance,450000,450000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),165,3,3,No,No recibo bono,Dos,40,6,Technical Leader,12,8,8,5,"Firebase, Linux, Microcontroladores, VMWare, Windows Server",".NET, Arduino, C#, Javascript, Swift",".NET Core, Angular, Flutter, SwiftUI","MariaDB, Microsoft SQL Server, MySQL",Ninguna de las anteriores,"Android Studio, NetBeans, Notepad++, Visual Studio, Visual Studio Code, Xcode",1-10,,Producto basado en Software,10,10,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,33,VarÃ³n Cis
#
# Chaco,Full-Time,70000,70000,,,2,2,No,No recibo bono,No,0,0,Developer,0,0,0,0,"Docker, Linux","CSS, HTML, Javascript, PHP",Drupal,MySQL,Ninguna de las anteriores,Visual Studio Code,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,8,0,"Clases de idiomas, Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Neto,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,23,VarÃ³n Cis
#
# Chaco,Tercerizado (trabajo a travÃ©s de consultora o agencia),223564,156795,,,3,3,No,No recibo bono,Tres,29,6,Developer,5,0,0,0,"Docker, Kubernetes, OpenShift","Java, Javascript, TypeScript","Hibernate, Spring",IBM Db2,"Postman, SoapUI, Mockito",IntelliJ,501-1000,,Otras industrias,8,8,Horarios flexibles,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,42,VarÃ³n Cis
#
# Chaco,Full-Time,150000,115000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),99.8,3,3,Un sueldo,Mix de las anteriores,Uno,50,3,Recruiter / HR,7,2,0,8,Ninguna de las anteriores,Ninguno de los anteriores,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Ninguno de los anteriores,10001+,,Producto basado en Software,10,10,"Abono de Internet, Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc), Horarios flexibles, Licencia de paternidad / maternidad extendida, Vacaciones flexibles (adicionales a las reglamentarias)",Quiero responder mÃ¡s preguntas,Posgrado,Completado,Lic. Psicologia,Ucasal,"SÃ­, de forma particular",No,No,Quiero responder mÃ¡s preguntas,No,0,Neto,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,3,0,1,Pareja,SÃ­,No,3,No,10,Se vio beneficiada,Pago de abono de Internet,34,Mujer Cis
#
# Chaco,Full-Time,100000,80000,,,2,3,No,No recibo bono,No,0,0,Developer,1,0,1,2,"Docker, Linux","HTML, Javascript","Bootstrap, Node.js, React.js","MongoDB, MySQL","Mocha, Postman","Vim, Visual Studio Code",1-10,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,9,9,Ninguna de las anteriores,Quiero responder mÃ¡s preguntas,Universitario,Incompleto,Lic. En Biotecnologia,Uncaus,"SÃ­, de forma particular",SÃ­,SÃ­,Quiero responder mÃ¡s preguntas,"SÃ­, pasiva",0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,4,0,0,Vivo solo/a,No,No,3,"CambiÃ© de trabajo, pero no por la pandemia",8,Se vio beneficiada,Ninguna de las anteriores,30,VarÃ³n Cis
#
# Chaco,Full-Time,280000,179000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),99.25,3,3,Menos de un sueldo,Mix de las anteriores,Uno,25,5,Developer,6,0,0,0,"Amazon Web Services, Docker, Serverless","Go, Java",GinGonic,Amazon DynamoDB,Pytest,IntelliJ,501-1000,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,9,10,"Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Comidas pagas / subvencionadas, Horarios flexibles",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,30,VarÃ³n Cis
#
# Chaco,Full-Time,182000,182000,,,4,3,No,No recibo bono,Uno,40,4,Developer,15,1,1,0,"Amazon Web Services, Azure, Docker, Kubernetes, Linux, Windows Server",".NET, ActionScript, C#, CSS, HTML, Javascript, SQL, TypeScript",".NET Core, Angular, Bootstrap, jQuery, SAP","Microsoft SQL Server, PostgreSQL",Ninguna de las anteriores,"Notepad++, Visual Studio, Visual Studio Code",51-100,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,8,9,"Capacitaciones y/o cursos, Clases de idiomas",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,41,VarÃ³n Cis
#
# Chaco,Full-Time,92180,74819,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),"100,25",2,4,No,No recibo bono,Uno,10,3,QA / Tester,1,1,1,0,"Docker, Linux","Bash/Shell, CSS, HTML, Java, Javascript",React.js,MongoDB,"Cucumber, JUnit, Postman, Selenium","Sublime Text, Visual Studio Code, WebStorm",10001+,,Servicios / ConsultorÃ­a de Software / Digital,10,10,"Abono de Internet, Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc), Horarios flexibles, Lactario en la oficina, Vacaciones flexibles (adicionales a las reglamentarias)",Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Bruto,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,24,VarÃ³n Cis
#
# Chaco,Remoto (empresa de otro paÃ­s),49500,44000,Cobro en dÃ³lares,,4,4,No,No recibo bono,No,0,0,Developer,0,0,0,0,"Amazon Web Services, Heroku",Javascript,Node.js,PostgreSQL,Jest,"Vim, Visual Studio Code",51-100,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,7,9,Clases de idiomas,Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en Sistemas de InformaciÃ³n,UNCAUS,"SÃ­, de forma particular",No,No,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,SÃ­,Ya colaborÃ© lo suficiente,,,,,,,,,,,,25,VarÃ³n Cis
#
# Chaco,Full-Time,70000,60000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),106,3,3,Un sueldo,Mix de las anteriores,No,0,0,Developer,1,0,0,0,"Docker, Linux","Java, Javascript","Node.js, Spring, TensorFlow",MySQL,"Jest, JUnit","IntelliJ, Visual Studio Code",101-200,,Servicios / ConsultorÃ­a de Software / Digital,9,9,"Abono de Internet, Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",No,SÃ­,Quiero responder mÃ¡s preguntas,"SÃ­, pasiva",20000,Neto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,No,Quiero responder mÃ¡s preguntas,4,0,0,Vivo solo/a,SÃ­,No,3,"CambiÃ© de trabajo, pero no por la pandemia",9,No la afectÃ³,"Clases de gimnasia, Clases de meditaciÃ³n, Clases de yoga, Pago de abono de Internet",31,VarÃ³n Cis
#
# Chaco,Full-Time,90000,75000,,,3,3,Menos de un sueldo,Performance individual,Uno,15,3,Developer,3,1,0,0,Windows Server,"CSS, HTML, Javascript, SQL","Angular, Bootstrap, jQuery, Node.js",Microsoft SQL Server,Ninguna de las anteriores,Visual Studio Code,501-1000,,Producto basado en Software,9,9,"Capacitaciones y/o cursos, Licencia de paternidad / maternidad extendida",Quiero responder mÃ¡s preguntas,Universitario,Completado,Licenciatura en AdministraciÃ³n,UCP,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,4,1,3,"Pareja, Hijos/as (tiempo completo)",No,No,4,ConseguÃ­ trabajo,9,"No la afectÃ³, Se vio beneficiada",Ninguna de las anteriores,34,VarÃ³n Cis
#
# Chaco,Full-Time,120000,106000,Cobro parte de mi sueldo en otro paÃ­s,,4,4,No,No recibo bono,Uno,20,4,QA / Tester,3,0,3,0,Ninguna de las anteriores,Javascript,Cypress,MySQL,Cypress,Visual Studio Code,101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,9,6,"Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Cuota para universidad / posgrados, Horarios flexibles, Lactario en la oficina, Licencia de paternidad / maternidad extendida, Vacaciones flexibles (adicionales a las reglamentarias)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,26,VarÃ³n Cis
#
# Chaco,Full-Time,191000,,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),,2,2,No,No recibo bono,Uno,27,1,Developer,5,2,2,0,"Docker, Linux","CSS, HTML, Javascript","jQuery, React.js",PostgreSQL,Ninguna de las anteriores,"Sublime Text, Visual Studio Code",2001-5000,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,8,10,"Abono de Internet, Capacitaciones y/o cursos, Clases de idiomas, Horarios flexibles",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,31,VarÃ³n Cis
#
# Chaco,Full-Time,122100,101000,,,2,2,No,No recibo bono,Uno,7,2,Developer,12,0,0,0,"Azure, Windows Server",".NET, Javascript",".NET Core, Bootstrap, React.js",Microsoft SQL Server,Ninguna de las anteriores,"Visual Studio, Visual Studio Code",11-50,,Otras industrias,8,0,Licencia de paternidad / maternidad extendida,Quiero responder mÃ¡s preguntas,Universitario,Incompleto,Licenciatura en InformÃ¡tica,Universidad Siglo 21,"SÃ­, de forma particular",SÃ­,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,2,0,3,Familia de origen (madre/padre/hermanos/as),No,No,3,DecidÃ­ buscar otro trabajo,8,Se vio beneficiada,"Compra de accesorios (escritorio, monitor, teclado, mouse, etc)",34,Prefiero no decir
#
# Chaco,Full-Time,71700,69053.78,,,2,2,No,No recibo bono,No,0,0,Developer,4,0,3,0,"Docker, Linux",PHP,"Bootstrap, jQuery, Symfony",MySQL,Ninguna de las anteriores,Visual Studio Code,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,8,0,Horarios flexibles,Quiero responder mÃ¡s preguntas,Terciario,En curso,Tecnicatura en ProgramaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,4,0,1,Familia de origen (madre/padre/hermanos/as),SÃ­,No,2,"CambiÃ© de trabajo, pero no por la pandemia",8,No la afectÃ³,Ninguna de las anteriores,28,VarÃ³n Cis
#
# Chaco,Full-Time,184184,,Cobro en dÃ³lares,101,3,4,De uno a tres sueldos,Performance individual,Dos,25,7,Developer,3,1,2,0,Amazon Web Services,"Bash/Shell, Go, Java",Ninguno de los anteriores,Amazon DynamoDB,"JUnit, Postman",IntelliJ,1001-2000,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,10,0,"Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Cuota para universidad / posgrados, Horarios flexibles, Licencia de paternidad / maternidad extendida, Vacaciones flexibles (adicionales a las reglamentarias), Reintegro de Spotify y Netflix",Quiero responder mÃ¡s preguntas,Terciario,Completado,Tecnicatura Superior en ProgramaciÃ³n,Teclab ,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,4,0,1,Pareja,No,No,4,DecidÃ­ buscar otro trabajo,10,No la afectÃ³,"Almuerzo o delivery de snacks/bebidas (saludables o para after office), Clases de gimnasia, Clases de meditaciÃ³n, Clases de yoga, Compra de accesorios (escritorio, monitor, teclado, mouse, etc), Pago de abono de otros servicios",24,VarÃ³n Cis
#
# Chaco,Full-Time,126000,100000,"Cobro parte de mi sueldo en otro paÃ­s, Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local)",96,3,4,No,No recibo bono,No,0,0,Developer,15,2,2,0,"Amazon Web Services, Docker","CSS, HTML, Javascript, PHP, SQL","jQuery, Node.js, React.js","MySQL, Redis",PHPUnit,PHPStorm,51-100,,Servicios / ConsultorÃ­a de Software / Digital,8,9,"Clases de idiomas, Comidas pagas / subvencionadas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc), Horarios flexibles, Stock options / RSUs",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,39,VarÃ³n Cis
#
# Chaco,Full-Time,84000,70000,,,4,4,No,No recibo bono,No,0,0,Developer,1,0,1,0,"Amazon Web Services, Heroku, Linux",Python,"Bootstrap, Django, jQuery","PostgreSQL, Redis",Ninguna de las anteriores,"Sublime Text, Visual Studio Code",1-10,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,8,0,"Horarios flexibles, Ninguna de las anteriores",Quiero responder mÃ¡s preguntas,Universitario,Incompleto,IngenierÃ­a en Sistemas de InformaciÃ³n,UNCAus,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,No,Quiero responder mÃ¡s preguntas,3,0,1,Pareja,No,SÃ­,3,"CambiÃ© de trabajo, pero no por la pandemia",9,No sÃ©.,No sÃ©.,26,VarÃ³n Cis
#
# Chaco,Part-Time,27500,22000,,,1,1,No,No recibo bono,No,0,0,Developer,5,0,0,0,"Amazon Web Services, Docker, Firebase, Linux","CSS, HTML, Javascript, PHP","Bootstrap, jQuery, React.js, WordPress",MySQL,Ninguna de las anteriores,Visual Studio Code,1-10,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,3,9,Ninguna de las anteriores,Quiero responder mÃ¡s preguntas,Terciario,Completado,Tecnicatura Superior en ProgramaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",SÃ­,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,1,0,2,"Pareja, Hermana mayor con discapacidad intelectual",No,No,4,Me despidieron,1,DespidiÃ³ a algunas personas,Ninguna de las anteriores,35,Mujer Cis
#
# Chaco,Part-Time,27500,22000,,,1,1,No,No recibo bono,No,0,0,Developer,5,0,0,0,"Amazon Web Services, Azure, Docker, Linux","CSS, HTML, Javascript, PHP, TypeScript","Bootstrap, Node.js, React.js, WordPress",MySQL,Ninguna de las anteriores,Visual Studio Code,1-10,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,1,9,Ninguna de las anteriores,Quiero responder mÃ¡s preguntas,Terciario,Completado,Tecnicatura Superior en ProgramaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",SÃ­,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Bruto,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,1,0,2,"Pareja, hermana con discapacidad intelectual",No,No,4,Me despidieron,1,DespidiÃ³ a algunas personas,Ninguna de las anteriores,35,Mujer Cis
#
# Chaco,Full-Time,189000,138000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),95,1,2,No,No recibo bono,No,0,0,Developer,3,1,3,0,"Amazon Web Services, Kubernetes, Linux","Bash/Shell, HTML, Javascript, TypeScript","Angular, React.js",MySQL,"Cypress, Jest, Mocha, Postman, Selenium",Emacs,101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,7,6,"Capacitaciones y/o cursos, Clases de idiomas",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,28,VarÃ³n Cis
#
# Chaco,Full-Time,92000,74600,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),100.21,2,4,No,No recibo bono,Uno,15,3,QA / Tester,1,1,1,0,"Docker, Google Cloud Platform/App Engine, Linux","Bash/Shell, Java, Javascript","jQuery, Node.js, React.js",Ninguna de las anteriores,"Cucumber, JUnit, Postman, Selenium","IntelliJ, Sublime Text, Visual Studio Code, WebStorm",10001+,,Servicios / ConsultorÃ­a de Software / Digital,10,10,"Abono de Internet, Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc), Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Neto,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,4,0,0,Vivo solo/a,SÃ­,No,2,No,10,No la afectÃ³,"Clases de gimnasia, Clases de yoga, Pago de abono de Internet, Work From Home",24,VarÃ³n Cis
#
# Chaco,Full-Time,84000,69856,,,3,3,Menos de un sueldo,Performance individual,No,0,0,Technical Business Analyst,0,0,0,0,Ninguna de las anteriores,Ninguno de los anteriores,Ninguno de los anteriores,MySQL,Ninguna de las anteriores,Visual Studio Code,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,8,9,"Clases de idiomas, Pago de hasta 3000 mensuales para lo que queramos",Quiero responder mÃ¡s preguntas,Universitario,En curso,Licenciatura en AdministraciÃ³n,UNNE- Universidad Nacional del Nordeste,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,28,Mujer Cis
#
# Chaco,Part-Time,retiro BRUTO,25000,,,2,2,No,No recibo bono,No,0,0,Developer,1,1,2,0,Ninguna de las anteriores,"CSS, HTML, Javascript","Bootstrap, Node.js, Vue.js",MySQL,Ninguna de las anteriores,Visual Studio Code,1-10,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,6,6,Horarios flexibles,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,25,VarÃ³n Cis
#
# Chaco,Full-Time,35000,35000,,,1,1,No,No recibo bono,No,0,0,Developer,0,0,0,0,"Amazon Web Services, Docker, Linux, Odoo","Javascript, Python, SQL",Odoo,PostgreSQL,Ninguna de las anteriores,Vim,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,6,10,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,25,VarÃ³n Cis
#
# Chaco,Full-Time,84000,66.8,,,2,3,No,No recibo bono,Dos,20,8,Developer,1.5,1.5,1.5,0,"Docker, Linux","CSS, HTML, Javascript","Bootstrap, Vue.js",Ninguna de las anteriores,Jest,Visual Studio Code,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,10,10,"Abono de celular, Capacitaciones y/o cursos, Clases de idiomas",Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,No,No,No,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,28,Mujer Cis
#
# Chaco,Full-Time,152000,116000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),98,3,3,No,Mix de las anteriores,No,0,0,QA / Tester,2,0,2,0,Ninguna de las anteriores,Ninguno de los anteriores,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Ninguno de los anteriores,101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,9,8,"Abono de Internet, Capacitaciones y/o cursos, Clases de idiomas, Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,En curso,ElectromecÃ¡nica,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Bruto,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,3,0,3,Familia de origen (madre/padre/hermanos/as),No,No,3,"CambiÃ© de trabajo, pero no por la pandemia",7,"CerrÃ³ oficinas, Se vio beneficiada","Clases de meditaciÃ³n, Compra de accesorios (escritorio, monitor, teclado, mouse, etc), Pago de abono de Internet",29,VarÃ³n Cis
#
# Chaco,Tercerizado (trabajo a travÃ©s de consultora o agencia),179.701,130.122,,,2,2,No,No recibo bono,Uno,40,3,Developer,7,2,1,2,Azure,".NET, C#, CSS, HTML, Javascript, TypeScript",".NET Core, Angular",Microsoft SQL Server,"Karma, Postman",Visual Studio Code,1-10,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,5,7,"Capacitaciones y/o cursos, Horarios flexibles",Quiero responder mÃ¡s preguntas,Terciario,Incompleto,Tecnicatura en ProgramaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Neto,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,35,VarÃ³n Cis
#
# Chaco,Full-Time,77104,64112,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),"100,74",3,4,Un sueldo,Aguinaldos,No,0,0,Designer,3,0,0,0,Ninguna de las anteriores,Ninguno de los anteriores,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Ninguno de los anteriores,101-200,,Servicios / ConsultorÃ­a de Software / Digital,9,9,"Abono de Internet, Capacitaciones y/o cursos, Clases de idiomas, Work from home",Quiero responder mÃ¡s preguntas,Universitario,Completado,DiseÃ±o GrÃ¡fico,UNNE ,"SÃ­, de forma particular",No,No,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Ya colaborÃ© lo suficiente,,,,,,,,,,,,29,Mujer
#
# Chaco,Full-Time,62450,52190,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),98,2,1,No,No recibo bono,Uno,12,4,QA / Tester,0,0,0,0,Amazon Web Services,Java,Ninguno de los anteriores,"ElasticSearch, Oracle",JUnit,"IntelliJ, Visual Studio Code",101-200,,Producto basado en Software,10,10,"Abono de Internet, Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc), Licencia de paternidad / maternidad extendida, Stock options / RSUs, Vacaciones flexibles (adicionales a las reglamentarias)",Quiero responder mÃ¡s preguntas,Terciario,En curso,Tecnicatura en ProgramaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",SÃ­,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,3,1,2,"Pareja, Hijos/as (tiempo completo)",No,No,2,DecidÃ­ buscar otro trabajo,10,Se vio beneficiada,"Clases de gimnasia, Clases de meditaciÃ³n, Clases de yoga, Compra de accesorios (escritorio, monitor, teclado, mouse, etc), Pago de abono de Internet",46,VarÃ³n Cis
#
# Chaco,Full-Time,80000,110000,,,3,3,Menos de un sueldo,Performance individual,Dos,50,6,Developer,3,1,1,0,Windows Server,"Javascript, SQL","Angular, Bootstrap, jQuery, Node.js",Microsoft SQL Server,Postman,Visual Studio Code,1001-2000,,Producto basado en Software,8,6,"Capacitaciones y/o cursos, Licencia de paternidad / maternidad extendida",Quiero responder mÃ¡s preguntas,Universitario,Completado,Licenciatura en AdministraciÃ³n,UCP - Universidad de la Cuenca del Plata,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Bruto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,No,Quiero responder mÃ¡s preguntas,3,1,2,Pareja,No,No,3,DecidÃ­ buscar otro trabajo,8,Se vio beneficiada,Ninguna de las anteriores,34,VarÃ³n Cis
#
# Chaco,Full-Time,122000,105000,,,1,1,No,No recibo bono,Uno,17,5,Administrador Infraestructura,13,5,5,2,Onpremise,"Python, SQL",Ninguno de los anteriores,"MariaDB, Microsoft SQL Server, MongoDB, MySQL",Ninguna de las anteriores,Visual Studio Code,2001-5000,,Otras industrias,5,3,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,34,Hombre
#
# Chaco,Full-Time,125000,105000,,,4,4,No,No recibo bono,No,0,0,Developer,0,0,0,0,Linux,Javascript,"Bootstrap, React.js, React Native",Ninguna de las anteriores,Jest,Visual Studio Code,10001+,,Servicios / ConsultorÃ­a de Software / Digital,9,10,"Abono de Internet, Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas",Quiero responder mÃ¡s preguntas,Secundario,Completado,,,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,3,0,1,Abuela,SÃ­,No,1,DecidÃ­ dejar la universidad y empezar a programar,10,No la afectÃ³,"Compra de accesorios (escritorio, monitor, teclado, mouse, etc), Pago de abono de Internet",23,Mujer Cis
#
# Chaco,Full-Time,85000,71000,,,2,1,Menos de un sueldo,Mix de las anteriores,No,0,0,Developer,3,3,3,0,Linux,"SQL, Genexus (ojalÃ¡ cuente xD)",Ninguno de los anteriores,Microsoft SQL Server,Ninguna de las anteriores,Notepad++,501-1000,,Producto basado en Software,6,0,ViÃ¡ticos,Quiero responder mÃ¡s preguntas,Universitario,Incompleto,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,3,0,1,Pareja,SÃ­,No,3,"la empresa tuvo que aceptar que el ""trabajo remoto"" es una forma de trabajo ",6,"muchos compaÃ±eros renunciaron y encontraron mejores trabajos , mejores pagos",Ninguna de las anteriores,32,VarÃ³n Cis
#
# Chaco,Full-Time,50000,40000,,,2,2,No,No recibo bono,No,0,0,QA / Tester,1,1,1,0,Docker,"Java, Ruby",Ninguno de los anteriores,"MongoDB, MySQL","Appium, Cucumber, Cypress, JUnit, Postman, Selenium, TestNG Serenity ",IntelliJ,10001+,,Producto basado en Software,8,10,"Abono de Internet, Capacitaciones y/o cursos, Clases de idiomas",Quiero responder mÃ¡s preguntas,Universitario,Completado,GeologÃ­a ,UNC - Universidad Nacional de CÃ³rdoba,"SÃ­, de forma particular",No,No,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,4,0,1,Pareja,SÃ­,No,3,CambiÃ© de rubro. EntrÃ© al rubro IT.,8,La empresa donde trabaja dejÃ³ de pagar sueldos. La actual se acomodÃ³ muy bien  no le afectÃ³. ,"Clases de meditaciÃ³n, Clases de yoga, Pago de abono de Internet",33,Mujer Cis
#
# Chaco,Full-Time,247000,20000,,,4,4,De uno a tres sueldos,Performance de la compaÃ±Ã­a,Uno,10,7,Data Scientist,2,0,0,0,Amazon Web Services,"Bash/Shell, Python",Ninguno de los anteriores,Teradata,Postman,"IPython / Jupyter, PyCharm, Visual Studio Code",10001+,Trabajo para una empresa que no tiene oficina en mi ciudad,Otras industrias,10,10,"Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Horarios flexibles, Lactario en la oficina, Licencia de paternidad / maternidad extendida, Vacaciones flexibles (adicionales a las reglamentarias)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,35,VarÃ³n Cis
#
# Chaco,Full-Time,80000,53000,,,4,3,Un sueldo,Votado por decisiÃ³n colectiva.,No,0,0,Developer,0,0,0,0,Ninguna de las anteriores,Javascript,"Django, Vue.js",Ninguna de las anteriores,Ninguna de las anteriores,Visual Studio Code,101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,10,8,"Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc)",Quiero responder mÃ¡s preguntas,Universitario,Completado,Analista de Sistemas,UNCAus,No,SÃ­,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,Visual,No,Quiero responder mÃ¡s preguntas,4,0,2,Familia de origen (madre/padre/hermanos/as),SÃ­,No,4,No,10,No la afectÃ³,0,23,VarÃ³n Cis
#
# Chubut,Full-Time,90000,74000,,,2,2,No,No recibo bono,No,0,0,BI Analyst / Data Analyst,4,0,0,0,Ninguna de las anteriores,Ninguno de los anteriores,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Ninguno de los anteriores,101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,10,7,"Clases de idiomas, Vacaciones flexibles (adicionales a las reglamentarias)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,29,Mujer Cis
#
# Chubut,Full-Time,45000,45000,,,1,2,No,No recibo bono,No,0,0,Designer,5,1,5,0,Ninguna de las anteriores,Ninguno de los anteriores,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Visual Studio Code,11-50,,Otras industrias,1,3,Horarios flexibles,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,35,VarÃ³n Cis
#
# Chubut,Full-Time,75500,75500,,,3,3,No,No recibo bono,Uno,20,4,Developer,1,0,0,0,"Amazon Web Services, Docker","CSS, HTML, Javascript, PHP, SQL","Bootstrap, jQuery, Laravel","MongoDB, MySQL",PHPUnit,Visual Studio Code,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,9,9,"Abono de Internet, Clases de idiomas, Horarios flexibles, Licencia de paternidad / maternidad extendida",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,30,VarÃ³n Cis
#
# Chubut,Full-Time,310000,,,,2,2,Menos de un sueldo,Mix de las anteriores,Uno,10,7,Developer,5,1,2,0,"Amazon Web Services, Google Cloud Platform/App Engine",Java,Spring,"Amazon DynamoDB, Cassandra, ElasticSearch, MySQL, Redis",JUnit,"IntelliJ, Visual Studio Code",10001+,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,5,8,"Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,27,VarÃ³n Cis
#
# Chubut,Remoto (empresa de otro paÃ­s),84000,,Cobro en dÃ³lares,,2,3,No,No recibo bono,No,0,0,Developer,0,0,0,0,Docker,"Bash/Shell, HTML, Kotlin, Python, SQL","Bootstrap, Django, Flask, Ninguno de los anteriores","Microsoft SQL Server, MongoDB, PostgreSQL",Ninguna de las anteriores,"Notepad++, Visual Studio Code",1-10,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,9,5,"Capacitaciones y/o cursos, Horarios flexibles, Vacaciones flexibles (adicionales a las reglamentarias)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,22,VarÃ³n Cis
#
# Chubut,Full-Time,206000,151000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),,3,2,No,No recibo bono,Tres,50,5,Developer,3,3,3,0,"Azure, Docker, Linux",".NET, C#",.NET Core,"Microsoft Azure (Tables, CosmosDB, SQL, etc)",Cypress,"Visual Studio, Visual Studio Code",101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,6,0,Horarios flexibles,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,31,Varon
#
# Chubut,Full-Time,130000,100000,,,3,3,Menos de un sueldo,Performance de la compaÃ±Ã­a,Uno,30,6,Developer,10,8,5,0,"Mainframe, Windows Server","Java, Genexus",Spring,IBM Db2,JUnit,"Eclipse, Notepad++, Descartes, Genexus",201-500,,Otras industrias,6,0,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,38,VarÃ³n Cis
#
# Chubut,Full-Time,170000,133000,,,3,4,No,No recibo bono,Dos,30,7,Developer,2,0,1,0,"Amazon Web Services, Docker, Linux, OpenStack","Bash/Shell, CSS, HTML, Javascript, PHP, SQL, TypeScript","Node.js, React.js","Amazon Redshift, ElasticSearch, MariaDB, MySQL, PostgreSQL",Jest,"Visual Studio Code, Xcode",11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,8,7,"Capacitaciones y/o cursos, Clases de idiomas, Horarios flexibles",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,26,VarÃ³n Cis
#
# Chubut,Remoto (empresa de otro paÃ­s),714000,595000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),168,4,4,No,No recibo bono,No,0,0,Developer,9,0,5,1,"Amazon Web Services, Docker, Linux","Javascript, PHP, TypeScript","Laravel, Node.js, Vue.js",PostgreSQL,"Jest, PHPUnit",Visual Studio Code,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,10,8,Vacaciones flexibles (adicionales a las reglamentarias),Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,34,VarÃ³n Cis
#
# Chubut,Full-Time,60000,55000,,,3,3,No,No recibo bono,No,0,0,HelpDesk,25,15,13,0,"Arduino o similar, Docker, Linux, Microcontroladores, Serverless, VMWare, Windows Server","ActionScript, Arduino, Assembler, CSS, HTML, Javascript, PHP, Python, SQL, VBA, Labview","Bootstrap, jQuery","MariaDB, Microsoft Azure (Tables, CosmosDB, SQL, etc), Microsoft SQL Server, MySQL, SQLite",OpenQA,"NetBeans, Notepad++, PHPStorm, Sublime Text, Visual Studio",11-50,,Otras industrias,7,7,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,46,VarÃ³n Cis
#
# Chubut,Full-Time,130560,108382,,,3,2,No,No recibo bono,Uno,19,4,Developer,15,2,2,0,"Arduino o similar, Linux, Proxmox","CSS, Javascript, PHP, SQL","Bootstrap, jQuery, Laravel, Node.js, React.js","MariaDB, MySQL, PostgreSQL, Redis","PHPUnit, Postman","Notepad++, Visual Studio Code",51-100,,Otras industrias,7,7,"Capacitaciones y/o cursos, Clases de idiomas, Comidas pagas / subvencionadas, Licencia de paternidad / maternidad extendida",Quiero responder mÃ¡s preguntas,Secundario,Completado,,,"SÃ­, de forma particular, SÃ­, los pagÃ³ un empleador",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Bruto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Ya colaborÃ© lo suficiente,,,,,,,,,,,,43,VarÃ³n Cis
#
# Chubut,Full-Time,175692,132000,,,2,2,No,No recibo bono,Uno,20,4,Developer,7.5,7.5,7.5,0,Oracle,Pl-SQL ,Oracle forms,Oracle,Ninguna de las anteriores,Oracle designer,11-50,,Producto basado en Software,6,5,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,30,Prefiero no decir
#
# Chubut,Full-Time,240000,150000,,,3,2,Un sueldo,Mix de las anteriores,Dos,40,7,Consultant,15,12,1,4,Peoplesoft,Peoplecode,Peopletools,"Microsoft SQL Server, Oracle",Ninguna de las anteriores,Ninguno de los anteriores,51-100,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,7,9,Clases de idiomas,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,40,VarÃ³n Cis
#
# Chubut,Full-Time,130000,130000,,,3,2,Un sueldo,"Es un ""aguinaldo"" a pesar que facturo.",No,0,0,DBA,15,2,13,1,"Amazon Web Services, Linux, Windows Server",SQL,Ninguno de los anteriores,"Amazon Redshift, Amazon RDS/Aurora, Microsoft SQL Server, MySQL",Ninguna de las anteriores,"Notepad++, Vim, Visual Studio Code",101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Otras industrias,7,0,"Capacitaciones y/o cursos, Horarios flexibles",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,48,VarÃ³n Cis
#
# Chubut,Full-Time,165754,132038,,,2,2,No,No recibo bono,No,0,0,help desk + backup + vmware + sys admin,11,11,11,0,"Linux, VMWare, Windows Server",Ninguno de los anteriores,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Ninguno de los anteriores,201-500,,Otras industrias,8,6,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,45,VarÃ³n Cis
#
# Chubut,Full-Time,175000,135000,,,2,1,No,No aplica,Uno,7,7,Manager / Director,20,17,10,9,"Docker, Linux, Windows Server","Javascript, PHP, Oracle","Angular, Node.js, WordPress","MariaDB, MySQL, Oracle",Ninguna de las anteriores,"Eclipse, Notepad++, Oracle DS",1001-2000,,Otras industrias,5,4,"Abono de celular, Licencia de paternidad / maternidad extendida",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,47,VarÃ³n Cis
#
# Chubut,Full-Time,170000,141000,,,3,4,Menos de un sueldo,Performance individual,Dos,30,7,Developer,2,0,0,0,"Amazon Web Services, Docker, Linux","Bash/Shell, CSS, HTML, Javascript, PHP, SQL, TypeScript","Node.js, React.js, Magento",Amazon RDS/Aurora,Ninguna de las anteriores,Visual Studio Code,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,7,5,"Abono de Internet, Capacitaciones y/o cursos, Clases de idiomas, Horarios flexibles, Vacaciones flexibles (adicionales a las reglamentarias)",Quiero responder mÃ¡s preguntas,Universitario,En curso,Analista Programador Universitario,UNPSJB - Universidad Nacional de la Patagonia San Juan Bosco,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Bruto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,No,Quiero responder mÃ¡s preguntas,3,0,1,Pareja,No,SÃ­,3,"CambiÃ© de trabajo, pero no por la pandemia",6,No la afectÃ³,"Compra de accesorios (escritorio, monitor, teclado, mouse, etc), Pago de abono de Internet",26,VarÃ³n Cis
#
# Chubut,Remoto (empresa de otro paÃ­s),90000,74000,,,2,1,No,No recibo bono,No,0,0,BI Analyst / Data Analyst,5,0,0,0,Ninguna de las anteriores,"Python, R",Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,IPython / Jupyter,101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Otras industrias,10,10,"Clases de idiomas, Vacaciones flexibles (adicionales a las reglamentarias)",Quiero responder mÃ¡s preguntas,Universitario,Incompleto,Licenciatura en Economia,Universidad nacional de la Patagonia San Juan bosco,"SÃ­, de forma particular",No,No,Quiero responder mÃ¡s preguntas,No,0,Neto,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,4,0,1,Pareja,SÃ­,No,4,DecidÃ­ buscar otro trabajo,10,No la afectÃ³,Ninguna de las anteriores,30,Mujer Cis
#
# Chubut,Full-Time,95000,90000,Mi sueldo estÃ¡ dolarizado (pero cobro en moneda local),180,2,2,No,No recibo bono,Dos,20,7,Consultant,13,11,11,0,Windows Server,Ninguno de los anteriores,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Ninguno de los anteriores,11-50,,Otras industrias,4,3,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,38,VarÃ³n Cis
#
# Ciudad AutÃ³noma de Buenos Aires,Full-Time,125000,105000,,,2,2,No,No recibo bono,Uno,10,3,QA / Tester,3,1,3,4,Azure,".NET, C#, Python, SQL",Ninguno de los anteriores,"Microsoft Azure (Tables, CosmosDB, SQL, etc), Microsoft SQL Server","Appium, Cucumber, HP UFT, JUnit, NUnit, Postman, Selenium, SoapUI","IntelliJ, Visual Studio, Visual Studio Code",201-500,,Servicios / ConsultorÃ­a de Software / Digital,8,9,"Abono de Internet, Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en InformÃ¡tica,UBA - Universidad de Buenos Aires,"SÃ­, de forma particular",No,No,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,22,VarÃ³n Cis
#
# Ciudad AutÃ³noma de Buenos Aires,Full-Time,128000,106000,,,2,2,No,No recibo bono,Uno,25,2,Developer,0,0,0,0,"Azure, Docker, Kubernetes",".NET, C#, Javascript",".NET Core, Node.js, React.js","MongoDB, PostgreSQL",Mocha,"Sublime Text, Visual Studio, Visual Studio Code",11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,9,0,Horarios flexibles,Quiero responder mÃ¡s preguntas,Universitario,En curso,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Bruto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,1,0,2,Familia de origen (madre/padre/hermanos/as),SÃ­,No,4,"CambiÃ© de trabajo, pero no por la pandemia",10,Se vio beneficiada,Ninguna de las anteriores,23,Prefiero no decir
#
# Ciudad AutÃ³noma de Buenos Aires,Remoto (empresa de otro paÃ­s),750000,750000,Cobro en dÃ³lares,,4,4,Un sueldo,Performance de la compaÃ±Ã­a,No,0,0,DBA,12,3,3,0,"Linux, Solaris, oracle ",SQL,Ninguno de los anteriores,Oracle,Ninguna de las anteriores,Ninguno de los anteriores,5001-10000,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,10,10,"Abono de celular, Abono de Internet",Quiero responder mÃ¡s preguntas,Universitario,Completado,IngenierÃ­a en Sistemas de InformaciÃ³n,UAI - Universidad Abierta Interamericana,No,No,No,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,2,1,2,"Pareja, Hijos/as (tiempo completo)",No,No,3,No,5,Se vio beneficiada,Ninguna de las anteriores,35,VarÃ³n Cis
#
# Ciudad AutÃ³noma de Buenos Aires,Tercerizado (trabajo a travÃ©s de consultora o agencia),149000,119000,,,3,3,No,No recibo bono,Dos,31,4,Developer,2,1,1,0,"Docker, OpenShift","CSS, HTML, Java, Javascript, TypeScript","Angular, Cordova, Node.js, Spring",MySQL,"Cucumber, JUnit, Karma, Selenium","Eclipse, Visual Studio Code",2001-5000,,Producto basado en Software,5,0,"Capacitaciones y/o cursos, Estacionamiento gratuito / subvencionado, Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,Completado,DiseÃ±o GrÃ¡fico,UBA - Universidad de Buenos Aires,"SÃ­, los pagÃ³ un empleador",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Ya colaborÃ© lo suficiente,,,,,,,,,,,,37,Mujer Cis
#
# Ciudad AutÃ³noma de Buenos Aires,Full-Time,"$105,000",83000,,,2,1,No,No recibo bono,Uno,20,3,SysAdmin / DevOps / SRE,15,10,8,1,"Azure, Linux, Windows Server","Bash/Shell, HTML, SQL",WordPress,Microsoft SQL Server,Ninguna de las anteriores,Ninguno de los anteriores,51-100,,Otras industrias,3,2,Horarios flexibles,Quiero responder mÃ¡s preguntas,Terciario,Completado,Analista en Redes InformÃ¡ticas,ESBA - Escuela Superior Buenos Aires,"SÃ­, de forma particular",No,No,Quiero responder mÃ¡s preguntas,"SÃ­, pasiva",0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En mi trabajo actual,,,Quiero responder mÃ¡s preguntas,4,1,2,"Pareja, Hijos/as (tiempo completo)",SÃ­,No,3,No,4,No la afectÃ³,Clases de yoga,46,VarÃ³n Cis
#
# ...
#
# CÃ³rdoba,Full-Time,197500,143000,,,3,4,No,No recibo bono,Dos,25,7,Data Scientist,2,0,0,0,"Amazon Web Services, Docker, Google Cloud Platform/App Engine","Python, R, SQL",Ninguno de los anteriores,"Amazon Redshift, MongoDB, MySQL, Neo4j, PostgreSQL",Ninguna de las anteriores,"IPython / Jupyter, RStudio, Visual Studio Code",501-1000,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,8,9,"Abono de Internet, Clases de idiomas, Horarios flexibles, Vacaciones flexibles (adicionales a las reglamentarias)",Quiero responder mÃ¡s preguntas,Posgrado,En curso,Licenciatura en AdministraciÃ³n,UNC - Universidad Nacional de CÃ³rdoba,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,25,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,201000,136800,,,2,2,Un sueldo,Mix de las anteriores,Uno,10,7,Developer,6,0,0,0,"Docker, Kubernetes, Linux",Python,"Django, Flask",MySQL,Ninguna de las anteriores,"IPython / Jupyter, Visual Studio Code",5001-10000,,Producto basado en Software,8,10,"Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,Completado,Tecnicatura Superior en ProgramaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,No,SÃ­,SÃ­,Quiero responder mÃ¡s preguntas,"SÃ­, pasiva",0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,4,0,1,Pareja,SÃ­,SÃ­,3,"CambiÃ© de trabajo, pero no por la pandemia",9,No la afectÃ³,"Clases de gimnasia, Clases de meditaciÃ³n, Clases de yoga, Compra de accesorios (escritorio, monitor, teclado, mouse, etc)",29,VarÃ³n Cis
#
# CÃ³rdoba,Remoto (empresa de otro paÃ­s),900000,800000,Cobro en dÃ³lares,176,3,3,No,No recibo bono,No,0,0,Developer,30,0,0,0,Ninguna de las anteriores,TypeScript,Angular,MySQL,"Cypress, Karma",Visual Studio Code,5001-10000,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,9,8,Ninguna de las anteriores,Quiero responder mÃ¡s preguntas,Universitario,Incompleto,Licenciatura en InformÃ¡tica,UB - Universidad de Belgrano,No,No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Porcentaje de mi sueldo,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,57,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,356000,220000,,,3,4,3+ sueldos,Mix de las anteriores,Uno,10,7,Technical Leader,9,1,1,0,Linux,"Bash/Shell, Python, SQL",Torch,Apache Hive,Ninguna de las anteriores,"Vim, Visual Studio Code",10001+,,Producto basado en Software,9,7,"Descuento en gimnasios / Clases de gimnasia online, Comidas pagas / subvencionadas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc), Horarios flexibles",Quiero responder mÃ¡s preguntas,Doctorado,Completado,Licenciatura en Ciencias de la ComputaciÃ³n,UNC - Universidad Nacional de CÃ³rdoba,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Neto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,3,1,2,"Pareja, Hijos/as (tiempo dividido)",SÃ­,No,2,No,5,Se vio beneficiada,"Almuerzo o delivery de snacks/bebidas (saludables o para after office), Clases de meditaciÃ³n, Clases de yoga, Compra de accesorios (escritorio, monitor, teclado, mouse, etc), DÃ­as libres extras",32,VarÃ³n Cis
#
# CÃ³rdoba,Freelance,300000,300000,,,4,4,No,No recibo bono,Tres,52,9,Developer,28,25,4,5,"Amazon Web Services, Windows Server",C#,.NET Core,Microsoft SQL Server,Ninguna de las anteriores,Ninguno de los anteriores,501-1000,Trabajo para una empresa que no tiene oficina en mi ciudad,Otras industrias,4,5,"Horarios flexibles, ViÃ¡ticos",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,50,Prefiero no decir
#
# CÃ³rdoba,Full-Time,172000,129000,,,3,3,No,No recibo bono,Tres,20,5,Developer,10,1,1,0,"Amazon Web Services, Docker","Javascript, SQL, TypeScript",Node.js,"Amazon RDS/Aurora, PostgreSQL",Jest,Visual Studio Code,101-200,,Servicios / ConsultorÃ­a de Software / Digital,7,9,Capacitaciones y/o cursos,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,30,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,70400,60000,,,3,3,No,No recibo bono,No,0,0,Developer,0,0,0,0,Firebase,"CSS, Javascript","Bootstrap, Node.js, React.js",MongoDB,Ninguna de las anteriores,Visual Studio Code,11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,10,10,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,41,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,90000,79000,,,2,2,No,No recibo bono,Uno,10,6,BI Analyst / Data Analyst,1,9,1,0,SAP,Ninguno de los anteriores,SAP,HANA,Ninguna de las anteriores,Ninguno de los anteriores,11-50,,Otras industrias,6,6,"Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Horarios flexibles, Licencia de paternidad / maternidad extendida, ViÃ¡ticos",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,29,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,180000,120000,,,2,2,De uno a tres sueldos,Mix de las anteriores,No,0,0,Developer,5,2,0,0,Ninguna de las anteriores,"Go, Groovy, Java",Spring,"ElasticSearch, MySQL",Ninguna de las anteriores,IntelliJ,10001+,,Producto basado en Software,9,10,"Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Horarios flexibles",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,25,VarÃ³n Cis
#
# CÃ³rdoba,Tercerizado (trabajo a travÃ©s de consultora o agencia),150000,122000,,,3,4,No,No recibo bono,Dos,72,7,Developer,6,3,1,0,"Docker, Linux","Bash/Shell, CSS, HTML, Javascript, PHP, Python, SQL, VBA","Laravel, Node.js, Vue.js","MariaDB, MySQL, Redis",PHPUnit,"Nano, Sublime Text, Visual Studio Code",51-100,,Producto basado en Software,7,0,"Capacitaciones y/o cursos, Comidas pagas / subvencionadas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,29,VarÃ³n Cis
#
# CÃ³rdoba,Remoto (empresa de otro paÃ­s),270000,250000,"Cobro en dÃ³lares, Cobro parte de mi sueldo en otro paÃ­s",172,4,4,No,No recibo bono,No,0,0,SysAdmin / DevOps / SRE,0,0,0,0,"Amazon Web Services, Serverless",Python,Ninguno de los anteriores,"Amazon DynamoDB, MongoDB, PostgreSQL",Ninguna de las anteriores,Visual Studio Code,51-100,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,10,10,"Capacitaciones y/o cursos, Clases de idiomas, Horarios flexibles, Vacaciones flexibles (adicionales a las reglamentarias)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,24,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,223000,156700,,,4,4,De uno a tres sueldos,Mix de las anteriores,No,0,0,Developer,4,2,2,0,"Amazon Web Services, Docker, Google Cloud Platform/App Engine, Kubernetes","Go, SQL",Ninguno de los anteriores,MySQL,Ninguna de las anteriores,IntelliJ,5001-10000,,Producto basado en Software,8,4,"Clases de idiomas, Comidas pagas / subvencionadas, Vacaciones flexibles (adicionales a las reglamentarias)",Quiero responder mÃ¡s preguntas,Universitario,Completado,Licenciatura en Ciencias de la ComputaciÃ³n,UNSL,No,No,No,Quiero responder mÃ¡s preguntas,"SÃ­, pasiva",0,Neto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,,Quiero responder mÃ¡s preguntas,3,0,0,Vivo solo/a,SÃ­,No,4,No,10,Se vio beneficiada,"Clases de meditaciÃ³n, Clases de yoga, Compra de accesorios (escritorio, monitor, teclado, mouse, etc)",32,VarÃ³n Cis
#
# CÃ³rdoba,Tercerizado (trabajo a travÃ©s de consultora o agencia),117000,96320,,,2,2,No,No recibo bono,Uno,30,7,Developer,2,2,2,0,Amazon Web Services,"CSS, Java, Javascript, TypeScript",Angular,Ninguna de las anteriores,Ninguna de las anteriores,Visual Studio Code,2001-5000,,Otras industrias,9,9,"Capacitaciones y/o cursos, Clases de idiomas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc), Estacionamiento gratuito / subvencionado, Horarios flexibles",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,32,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,150000,,,,3,3,No,No recibo bono,Uno,12,6,SysAdmin / DevOps / SRE,1,1,1,0,"Amazon Web Services, Azure, Docker, Google Cloud Platform/App Engine, Kubernetes, Linux, Microcontroladores, OpenShift, OpenStack, VMWare, Ninguna de las anteriores",Python,Ninguno de los anteriores,Microsoft SQL Server,Selenium,Visual Studio Code,1001-2000,Trabajo para una empresa que no tiene oficina en mi ciudad,Servicios / ConsultorÃ­a de Software / Digital,5,8,"Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Comidas pagas / subvencionadas, Horarios flexibles",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,37,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,180000,130000,,,3,3,No,No recibo bono,Dos,30,6,Networking,20,17,10,3,Windows Server,Ninguno de los anteriores,Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Ninguno de los anteriores,501-1000,,Otras industrias,9,9,"Abono de celular, Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Estacionamiento gratuito / subvencionado",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,47,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,126000,105000,,,3,3,Menos de un sueldo,Performance individual,Dos,40,5,QA / Tester,4,14,4,0,Docker,".NET, Java, VBA",.NET Core,"Apache HBase, Microsoft SQL Server, MySQL",Tosca,"Eclipse, NetBeans, Notepad++, Visual Studio",11-50,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,6,5,Horarios flexibles,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,45,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,175000,1317720,,,2,3,No,No recibo bono,Dos,13,7,SysAdmin / DevOps / SRE,20,0,0,0,"Amazon Web Services, Docker, Kubernetes, Linux","Bash/Shell, Python",Ninguno de los anteriores,"Amazon DynamoDB, Amazon RDS/Aurora, ElasticSearch, PostgreSQL",Ninguna de las anteriores,Visual Studio Code,101-200,Trabajo para una empresa que no tiene oficina en mi ciudad,Producto basado en Software,7,8,"Capacitaciones y/o cursos, Horarios flexibles, Vacaciones flexibles (adicionales a las reglamentarias)",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,42,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,170000,132000,,,2,2,No,No recibo bono,Uno,12,3,Developer,21,20,15,2,Windows Server,"SQL, Vb6",Ninguno de los anteriores,Microsoft SQL Server,Ninguna de las anteriores,Visual Studio,201-500,,Producto basado en Software,7,5,"Abono de celular, Estacionamiento gratuito / subvencionado",Quiero responder mÃ¡s preguntas,Posgrado,Completado,IngenierÃ­a en Sistemas de InformaciÃ³n,UTN - Universidad TecnolÃ³gica Nacional,"SÃ­, de forma particular",No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Bruto,Quiero responder mÃ¡s preguntas,JamÃ¡s,,No,Quiero responder mÃ¡s preguntas,3,2,3,"Pareja, Hijos/as (tiempo completo)",No,No,1,No,6,No la afectÃ³,Ninguna de las anteriores,46,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,88500,73500,,,3,3,No,No recibo bono,No,0,0,Developer,0,0,0,0,Linux,"Javascript, TypeScript",React native,Ninguna de las anteriores,Jest,"Android Studio, Visual Studio Code",201-500,,Producto basado en Software,8,8,"Abono de Internet, Clases de idiomas, Comidas pagas / subvencionadas",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,24,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,18000,135000,,,3,4,No,No recibo bono,Uno,20,4,SysAdmin / DevOps / SRE,15,13,3,3,"Docker, Google Cloud Platform/App Engine, Linux, Serverless, VMWare, Windows Server","Bash/Shell, Python, SQL","Laravel, Node.js, WordPress","Google Cloud Storage, Microsoft SQL Server, MongoDB, MySQL, PostgreSQL, Redis",Ninguna de las anteriores,"Nano, Notepad++, PyCharm, Vi, Visual Studio Code",1001-2000,,Otras industrias,8,4,"Abono de celular, Capacitaciones y/o cursos, Clases de idiomas, Estacionamiento gratuito / subvencionado",Quiero responder mÃ¡s preguntas,Universitario,Incompleto,IngenierÃ­a en ComputaciÃ³n,UNC - Universidad Nacional de CÃ³rdoba,"SÃ­, de forma particular",No,No,Quiero responder mÃ¡s preguntas,"SÃ­, activa",9000,Neto,Quiero responder mÃ¡s preguntas,JamÃ¡s,Visual,SÃ­,Quiero responder mÃ¡s preguntas,4,0,2,Pareja,SÃ­,No,3,No,10,Bajaron los sueldos o pagan parte,Ninguna de las anteriores,38,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,250000,,,,4,3,De uno a tres sueldos,Mix de las anteriores,Uno,10,7,Data Engineer,3,0,0,0,Ninguna de las anteriores,Python,Ninguno de los anteriores,Apache Hive,Ninguna de las anteriores,Visual Studio Code,10001+,,Producto basado en Software,8,9,"Capacitaciones y/o cursos, Descuento en gimnasios / Clases de gimnasia online, Clases de idiomas, Comidas pagas / subvencionadas, Descuentos varios (Mercado Pago, ClarÃ­n 365, Club La NaciÃ³n, etc), Horarios flexibles",Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,28,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,65000,55000,,,1,2,No,No recibo bono,No,0,0,SysAdmin / DevOps / SRE,0,0,0,0,"Linux, VMWare, Windows Server",".NET, Bash/Shell, Javascript",.NET Core,"MySQL, PostgreSQL",Ninguna de las anteriores,Visual Studio,101-200,,Otras industrias,7,1,Comidas pagas / subvencionadas,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,32,VarÃ³n Cis
#
# CÃ³rdoba,Part-Time,77000,77000,,,2,2,No,No recibo bono,Uno,18,5,Responsable de Ã¡rea de sistemas ,16,3,3,1,"Linux, Windows Server, TOTVS",SQL,ningunio,Microsoft SQL Server,ninguno,ninguno,51-100,,Otras industrias,3,3,Ninguna de las anteriores,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,,,,,,,,,,,,,35,VarÃ³n Cis
#
# CÃ³rdoba,Full-Time,98800,84116,,,4,4,No,No recibo bono,Uno,7,7,Soporte Nivel 2,4,0,3,0,"Docker, Linux, VMWare, Windows Server","HTML, Javascript, PHP",Ninguno de los anteriores,Ninguna de las anteriores,Ninguna de las anteriores,Ninguno de los anteriores,11-50,,Servicios / ConsultorÃ­a de Software / Digital,9,9,"Capacitaciones y/o cursos, Clases de idiomas, Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,Completado,Ingenieria en Redes y Comunicaciones,Universidad Tecnologica del Centro - Venezuela,No,No,No,Quiero responder mÃ¡s preguntas,"SÃ­, activa",0,Porcentaje de mi sueldo,Quiero responder mÃ¡s preguntas,En un trabajo anterior,,,Quiero responder mÃ¡s preguntas,3,0,2,Familia de origen (madre/padre/hermanos/as),No,SÃ­,3,"CambiÃ© de trabajo, pero no por la pandemia",9,No la afectÃ³,Ninguna de las anteriores,28,VarÃ³n Cis
#
# CÃ³rdoba,Part-Time,12000,12000,,,2,1,No,No recibo bono,No,0,0,Developer,0,0,0,1,Windows Server,".NET, C#, CSS, HTML, SQL",".NET Core, Bootstrap, jQuery",Microsoft SQL Server,Ninguna de las anteriores,"Visual Studio, Visual Studio Code",1-10,,Producto basado en Software,8,1,"Capacitaciones y/o cursos, Horarios flexibles",Quiero responder mÃ¡s preguntas,Universitario,En curso,Licenciatura en Ciencias de la ComputaciÃ³n,UNC - Universidad Nacional de CÃ³rdoba,No,No,SÃ­,Quiero responder mÃ¡s preguntas,No,0,Neto,Ya colaborÃ© lo suficiente,,,,,,,,,,,,,,,,28,Mujer Cis
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_340/2115906707.py in <module>
#       4
#       5 with open(f"{path_to_file_1}", "r") as f:
# ----> 6     for linea in iter(f.readline, ''):
#       7         print(linea)
#       8
#
# ~\miniconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x81 in position 1342: character maps to <undefined>
